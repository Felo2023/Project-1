# %%
import pandas as pd
import matplotlib as plt
from pathlib import Path

# %%
data=[]
for i in range(4):
    
    datalocation=f'../Data/Covid202{i}-1000.csv'
    data.append(pd.read_csv(datalocation).drop({'FECHA_ACTUALIZACION',
                                                'ORIGEN',
                                                'NEUMONIA',
                                                'HABLA_LENGUA_INDIG',
                                                'OTRA_COM',
                                                'TABAQUISMO',
                                                'OTRO_CASO',
                                                'TOMA_MUESTRA_LAB',
                                                'TOMA_MUESTRA_ANTIGENO',
                                                'MIGRANTE',
                                                'PAIS_NACIONALIDAD'}
                                                ,axis=1))
    print(datalocation)
# Out:
# ../Data/Covid2020-1000.csv
# ../Data/Covid2021-1000.csv
# ../Data/Covid2022-1000.csv
# ../Data/Covid2023-1000.csv

# %%
data[0].head()
# Out:
#   ID_REGISTRO  SECTOR  ENTIDAD_UM  SEXO  ENTIDAD_NAC  ENTIDAD_RES  \
# 0      z4d6fe       6          24     1           24           24
# 1      z2a3cf       6          24     2           24           24
# 2      z1e370      12          14     1           14           14
# 3      z3bf80      12           8     2            8            8
# 4      zz7067      12           9     2            9            9
#
#    MUNICIPIO_RES  TIPO_PACIENTE FECHA_INGRESO FECHA_SINTOMAS  ... INMUSUPR  \
# 0             28              1    06/12/2020     30/11/2020  ...        2
# 1             28              1    20/02/2020     18/02/2020  ...        2
# 2             85              1    22/04/2020     18/04/2020  ...        2
# 3             37              1    28/07/2020     20/07/2020  ...        2
# 4              7              1    18/08/2020     17/08/2020  ...        2
#
#    HIPERTENSION  CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  RESULTADO_LAB  \
# 0             2               2         2              2              1
# 1             2               2         2              2             97
# 2             2               2         2              2              2
# 3             2               2         2              2              1
# 4             1               2         2              2              2
#
#    RESULTADO_ANTIGENO  CLASIFICACION_FINAL  PAIS_ORIGEN  UCI
# 0                  97                    3           97   97
# 1                  97                    6           97   97
# 2                  97                    7           97   97
# 3                  97                    3           97   97
# 4                  97                    7           97   97
#
# [5 rows x 29 columns]

# %%
data[0].drop('FECHA_ACTUALIZACION',axis=1)
# Out:
#     ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  ENTIDAD_NAC  ENTIDAD_RES  \
# 0        z4d6fe       1       6          24     1           24           24
# 1        z2a3cf       1       6          24     2           24           24
# 2        z1e370       1      12          14     1           14           14
# 3        z3bf80       2      12           8     2            8            8
# 4        zz7067       1      12           9     2            9            9
# ..          ...     ...     ...         ...   ...          ...          ...
# 995      077cef       1       4          11     2           11           11
# 996      0c3c43       1       4          23     1           31           23
# 997      056c65       1      12           8     2            8            8
# 998      17c34a       1       4          16     2           16           16
# 999      1b3a24       1       4          16     1           16           16
#
#      MUNICIPIO_RES  TIPO_PACIENTE FECHA_INGRESO  ... OTRO_CASO  \
# 0               28              1    06/12/2020  ...         2
# 1               28              1    20/02/2020  ...         1
# 2               85              1    22/04/2020  ...         2
# 3               37              1    28/07/2020  ...         2
# 4                7              1    18/08/2020  ...         2
# ..             ...            ...           ...  ...       ...
# 995             27              1    07/01/2020  ...        99
# 996              1              2    07/01/2020  ...        99
# 997             12              2    07/01/2020  ...         2
# 998             52              2    07/01/2020  ...        99
# 999             52              2    05/01/2020  ...        99
#
#     TOMA_MUESTRA_LAB  RESULTADO_LAB  TOMA_MUESTRA_ANTIGENO  \
# 0                  1              1                      2
# 1                  2             97                      2
# 2                  1              2                      2
# 3                  1              1                      2
# 4                  1              2                      2
# ..               ...            ...                    ...
# 995                2             97                      2
# 996                1              2                      2
# 997                1              2                      2
# 998                1              2                      2
# 999                1              2                      2
#
#      RESULTADO_ANTIGENO  CLASIFICACION_FINAL  MIGRANTE  PAIS_NACIONALIDAD  \
# 0                    97                    3        99             México
# 1                    97                    6        99             México
# 2                    97                    7        99             México
# 3                    97                    3        99             México
# 4                    97                    7        99             México
# ..                  ...                  ...       ...                ...
# 995                  97                    6        99             México
# 996                  97                    7        99             México
# 997                  97                    7        99             México
# 998                  97                    7        99             México
# 999                  97                    7        99             México
#
#      PAIS_ORIGEN  UCI
# 0             97   97
# 1             97   97
# 2             97   97
# 3             97   97
# 4             97   97
# ..           ...  ...
# 995           97   97
# 996           97   99
# 997           97   99
# 998           97   99
# 999           97   99
#
# [1000 rows x 39 columns]
